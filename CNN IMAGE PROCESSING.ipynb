# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %%
(xtrain,ytrain),(xtest,ytest)=datasets.cifar10.load_data()

# %%
xtrain.shape
# Out:
# (50000, 32, 32, 3)

# %%
#scaling the dataset
xtrain=xtrain/255
xtest=xtest/255

# %%
ytrain
# Out:
# array([[6],
#        [9],
#        [9],
#        ...,
#        [9],
#        [1],
#        [1]], dtype=uint8)

# %%
plt.figure(figsize=(13,1))
plt.imshow(xtrain[0])

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
classes[ytrain[2][0]]
# Out:
# 'truck'

# %%
#ann

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(3000,activation="relu"),
    keras.layers.Dense(1000,activation="relu"),
    keras.layers.Dense(10,activation="softmax")
])

# %%
model.compile(optimizer="SGD",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(xtrain,ytrain,epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 117s 75ms/step - loss: 1.8145 - accuracy: 0.3534
# Epoch 2/5
# 1563/1563 [==============================] - 118s 76ms/step - loss: 1.6221 - accuracy: 0.4267
# Epoch 3/5
# 1563/1563 [==============================] - 117s 75ms/step - loss: 1.5418 - accuracy: 0.4545
# Epoch 4/5
# 1563/1563 [==============================] - 117s 75ms/step - loss: 1.4852 - accuracy: 0.4775
# Epoch 5/5
# 1563/1563 [==============================] - 116s 74ms/step - loss: 1.4343 - accuracy: 0.4947

# %%
model.evaluate(xtrain,ytrain)
# Out:
# 1563/1563 [==============================] - 29s 18ms/step - loss: 1.4243 - accuracy: 0.4940
# [1.4243301153182983, 0.4940199851989746]

# %%
ypred=model.predict(xtest)
# Out:
# 313/313 [==============================] - 6s 18ms/step

# %%
ypred
# Out:
# array([[0.03399234, 0.13402194, 0.1201375 , ..., 0.00835786, 0.04128671,
#         0.00918938],
#        [0.06298496, 0.3268242 , 0.00458037, ..., 0.00303084, 0.06233098,
#         0.5308301 ],
#        [0.4106428 , 0.24867672, 0.00727641, ..., 0.00415327, 0.16920836,
#         0.14724551],
#        ...,
#        [0.00299532, 0.00209445, 0.16735707, ..., 0.05950801, 0.00849851,
#         0.00589405],
#        [0.05597133, 0.02716003, 0.20173486, ..., 0.04490984, 0.00509603,
#         0.01232064],
#        [0.03715165, 0.00790479, 0.09251899, ..., 0.52641666, 0.00358524,
#         0.01055156]], dtype=float32)

# %%
ypred=[np.argmax(i) for i in ypred]

# %%
ypred
# Out:
# [3,
#  9,
#  0,
#  0,
#  4,
#  6,
#  3,
#  4,
#  5,
#  1,
#  0,
#  9,
#  1,
#  7,
#  1,
#  8,
#  7,
#  5,
#  8,
#  6,
#  1,
#  0,
#  0,
#  1,
#  4,
#  6,
#  4,
#  0,
#  1,
#  6,
#  6,
#  4,
#  4,
#  5,
#  9,
#  1,
#  5,
#  1,
#  1,
#  5,
#  0,
#  6,
#  9,
#  4,
#  0,
#  9,
#  5,
#  0,
#  4,
#  4,
#  9,
#  4,
#  6,
#  3,
#  8,
#  0,
#  5,
#  1,
#  5,
#  5,
#  7,
#  3,
#  1,
#  9,
#  5,
#  2,
#  1,
#  0,
#  5,
#  9,
#  4,
#  7,
#  0,
#  8,
#  0,
#  2,
#  9,
#  5,
#  3,
#  1,
#  0,
#  1,
#  1,
#  5,
#  2,
#  7,
#  2,
#  0,
#  0,
#  9,
#  0,
#  4,
#  8,
#  6,
#  4,
#  5,
#  4,
#  0,
#  0,
#  7,
#  4,
#  4,
#  6,
#  3,
#  1,
#  1,
#  5,
#  6,
#  1,
#  7,
#  4,
#  0,
#  4,
#  4,
#  9,
#  1,
#  0,
#  7,
#  2,
#  7,
#  9,
#  4,
#  1,
#  2,
#  0,
#  1,
#  0,
#  5,
#  4,
#  0,
#  4,
#  1,
#  1,
#  9,
#  1,
#  3,
#  9,
#  7,
#  2,
#  8,
#  2,
#  1,
#  1,
#  5,
#  1,
#  5,
#  6,
#  5,
#  5,
#  5,
#  0,
#  1,
#  0,
#  0,
#  0,
#  5,
#  5,
#  9,
#  5,
#  0,
#  0,
#  1,
#  5,
#  4,
#  0,
#  7,
# ...

# %%
tf.math.confusion_matrix(ytest,ypred)
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[693,  61,  26,   5,  37,  60,  10,  40,  31,  37],
#        [ 48, 733,   6,   7,  14,  41,  10,  32,  12,  97],
#        [137,  38, 288,  33, 164, 194,  51,  75,   8,  12],
#        [ 53,  39,  48, 164,  79, 446,  46,  73,   8,  44],
#        [ 88,  29, 101,  18, 458, 137,  57,  98,   4,  10],
#        [ 35,  26,  60,  74,  79, 582,  37,  75,   8,  24],
#        [ 20,  32,  68,  48, 191, 201, 380,  37,   6,  17],
#        [ 51,  36,  34,  25,  79, 148,  11, 577,   1,  38],
#        [327, 135,  12,  11,  27,  61,   5,  21, 335,  66],
#        [ 67, 291,   9,  16,  13,  54,  19,  52,   8, 471]])>

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.4681

# %%
#accuracy is low so lets implement and see for cnn model

# %%
cnnmodel=keras.Sequential([
    keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation="relu",input_shape=(32,32,3)),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(filters=64,kernel_size=(3,3),activation="relu"),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(64,activation="relu"),
    keras.layers.Dense(10,activation="softmax")

    

])
cnnmodel.compile(optimizer="adam", loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(xtrain,ytrain,epochs=5)

#accuracy will be very low because we are using keras whereas we sholud use models.sequentils
#below is the implementation
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 113s 72ms/step - loss: 1.3912 - accuracy: 0.5117
# Epoch 2/5
# 1563/1563 [==============================] - 115s 74ms/step - loss: 1.3525 - accuracy: 0.5234
# Epoch 3/5
# 1563/1563 [==============================] - 116s 74ms/step - loss: 1.3173 - accuracy: 0.5378
# Epoch 4/5
# 1563/1563 [==============================] - 117s 75ms/step - loss: 1.2860 - accuracy: 0.5501
# Epoch 5/5
# 1563/1563 [==============================] - 117s 75ms/step - loss: 1.2545 - accuracy: 0.5593

# %%
from tensorflow.keras import layers,models

# %%
cnn = models.Sequential([
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),
    
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
cnn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
cnn.fit(xtrain, ytrain, epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 35s 22ms/step - loss: 1.4469 - accuracy: 0.4815
# Epoch 2/5
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.1032 - accuracy: 0.6144
# Epoch 3/5
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.9833 - accuracy: 0.6579
# Epoch 4/5
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.9028 - accuracy: 0.6842
# Epoch 5/5
# 1563/1563 [==============================] - 36s 23ms/step - loss: 0.8317 - accuracy: 0.7106

# %%
#better accuracy then ann in only 5 epochs

# %%
cnn.evaluate(xtest,ytest)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.9388 - accuracy: 0.6820
# [0.9388034343719482, 0.6819999814033508]

# %%
y_pred = cnn.predict(xtest)
y_pred[:5]
# Out:
# 313/313 [==============================] - 3s 8ms/step
# array([[5.4413918e-04, 1.1707009e-03, 1.1593576e-03, 7.1727633e-01,
#         5.9628097e-04, 2.2814360e-01, 4.7377747e-02, 2.5524714e-04,
#         3.3268018e-03, 1.4969664e-04],
#        [4.3246068e-02, 2.4256395e-01, 1.2512131e-04, 9.1803151e-05,
#         1.4728867e-06, 8.7493518e-06, 4.5933016e-06, 2.9870064e-06,
#         7.0727128e-01, 6.6840467e-03],
#        [2.0727438e-01, 2.9171029e-01, 1.4558485e-02, 2.9222967e-02,
#         7.4631777e-03, 8.8497028e-03, 8.6717168e-04, 5.1500667e-03,
#         3.4122697e-01, 9.3676791e-02],
#        [8.2915974e-01, 5.7888333e-02, 3.8244095e-02, 2.0082204e-03,
#         7.9657193e-03, 1.7076809e-04, 2.6287336e-04, 1.5176383e-04,
#         6.1858688e-02, 2.2898517e-03],
#        [1.2559195e-04, 1.2375100e-04, 2.4674313e-02, 1.9919422e-01,
#         2.3939084e-01, 8.0694385e-02, 4.5419204e-01, 7.8085816e-04,
#         8.0828642e-04, 1.5623991e-05]], dtype=float32)

# %%
y_classes = [np.argmax(element) for element in y_pred]
y_classes[:5]
# Out:
# [3, 8, 8, 0, 6]

# %%
ytest[:5]
# Out:
# array([[3],
#        [8],
#        [8],
#        [0],
#        [6]], dtype=uint8)

# %%
classes[y_classes[3]]
# Out:
# 'airplane'

# %%
classes[ytest[3][0]]
# Out:
# 'airplane'
